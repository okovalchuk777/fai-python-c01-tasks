# %% [markdown]
# ## Основы языка Python для аналитиков (семинары)
# ### Урок 3. Изменение таблиц в Pandas

# %%
import pandas as pd
import numpy as np

# %%
# https://stackoverflow.com/questions/49188960/how-to-show-all-columns-names-on-a-large-pandas-dataframe
# You can globally set printing options. This will allow you to see all column names & rows when you are doing .head().
# None of the column name will be truncated.
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# ### Задача 1

# %% [markdown]
# #### Скачать файл в уроке kc_house_data.csv и считать данные с помощью pandas

# %%
df = pd.read_csv("./kc_house_data.csv")

# %% [markdown]
# Описание датасета:

# %% [markdown]
# The dataset contains house sale prices for King County, which includes Seattle. It includes home sold between May 2014 and May 2015

# %% [markdown]
# Описание столбцов:

# %% [markdown]
# **id** :a notation for a house<br>
# **date**: Date house was sold (Дата дом был продан)<br>
# **price**: Price is prediction target (Цена является прогнозной целью)<br>
# **bedrooms**: Number of Bedrooms/House (Количество спален)<br>
# **bathrooms**: Number of bathrooms/bedrooms (Количество ванных комнат)<br>
# **sqft_living**: square footage of the home (Площадь дома)<br>
# **sqft_lot**: square footage of the lot (Площадь дома со двором)<br>
# **floors**:Total floors (levels) in house (Общее количество этажей (уровней) в доме)<br>
# **waterfront**: House which has a view to a waterfront (Дом с видом на набережную)<br>
# **view**: Has been viewed (Вид)<br>
# **condition**: How good the condition is Overall (Насколько хорошее состояние в целом)<br>
# **grade**: overall grade given to the housing unit, based on King County grading system (общий класс, присвоенный жилищной единице)<br>
# **sqft_above**:square footage of house apart from basement (Площадь дома без подвала)<br>
# **sqft_basement**: square footage of the basement (Площадь подвала)<br>
# **yr_built**: Built Year (Год постройки)<br>
# **yr_renovated**:Year when house was renovated (Год, когда дом был отремонтирован)<br>
# **zipcode**:zip code (Индекс)<br>
# **lat**: Latitude coordinate (Координата широты)<br>
# **long**: Longitude coordinate (Координата долготы)<br>
# **sqft_living15**: Living room area in 2015 (implies-- some renovations) This might or might not have affected the lotsize area (Площадь гостиной в 2015 году (подразумевает - некоторые ремонты) Это могло повлиять или не повлиять на площадь lotsize)<br>
# **sqft_lot15**: lotSize area in 2015 (implies-- some renovations) (Площадь lotSize в 2015 году (подразумевается - некоторые ремонтные работы))<br>
# Примечание:<br>
# 1 (square foot) = 0.09290304 square meters

# %% [markdown]
# #### Вывести на экран первые 5 строк

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# If you just want to see the column names you can do:

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома. Если реновации дома не было, то в новом признаке поставьте 0

# %%
# df.yr_built.value_counts()

# %%
# df.yr_renovated.value_counts()

# %%
df.yr_built.isnull().sum()
# Out:
# 0

# %%
df[df["yr_built"] == 0].shape[0]
# Out:
# 0

# %%
df.yr_renovated.isnull().sum()
# Out:
# 0

# %%
df[df["yr_renovated"] == 0].shape[0]
# Out:
# 20699

# %%
# yr_built_list = df['yr_built'].to_list()
# yr_built_list = np.unique(yr_built_list)
# yr_built_list

# %%
df["delta_renovated"] = 0

# %%
df.loc[df['yr_renovated'] != 0, 'delta_renovated'] = pd.Series.abs(df['yr_built'] - df['yr_renovated'])

# %%
# df["delta_renovated"].value_counts()

# %%
df[df["delta_renovated"] != 0][["yr_built", "yr_renovated", "delta_renovated"]].head(20)
# Out:
#      yr_built  yr_renovated  delta_renovated
# 1        1951          1991               40
# 35       1930          2002               72
# 95       1946          1991               45
# 103      1950          2010               60
# 115      1900          1999               99
# 125      1914          1992               78
# 158      1916          2013               97
# 209      1920          1994               74
# 216      1957          1991               34
# 230      1915          1978               63
# 237      1904          2005              101
# 269      1982          2008               26
# 274      1954          2003               49
# 282      1905          1994               89
# 324      1922          1984               62
# 325      1922          1984               62
# 330      1951          2002               51
# 358      1928          1954               26
# 379      1904          2014              110
# 398      1909          2011              102

# %%
df[df["delta_renovated"] != 0][["yr_built", "yr_renovated", "delta_renovated"]].shape[0]
# Out:
# 914

# %% [markdown]
# Создайте признаки года продажи, месяца продажи

# %%
df["year_of_sale"] = df["date"].apply(lambda x: x[:4])
df["month_of_sale"] = df["date"].apply(lambda x: x[4:6])

# %%
df[["date", "year_of_sale", "month_of_sale"]].head()
# Out:
#               date year_of_sale month_of_sale
# 0  20141013T000000         2014            10
# 1  20141209T000000         2014            12
# 2  20150225T000000         2015            02
# 3  20141209T000000         2014            12
# 4  20150218T000000         2015            02

# %%
df["year_of_sale"].value_counts()
# Out:
# 2014    14633
# 2015     6980
# Name: year_of_sale, dtype: int64

# %%
df["month_of_sale"].value_counts()
# Out:
# 05    2414
# 04    2231
# 07    2211
# 06    2180
# 08    1940
# 10    1878
# 03    1875
# 09    1774
# 12    1471
# 11    1411
# 02    1250
# 01     978
# Name: month_of_sale, dtype: int64

# %% [markdown]
# Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns=['date', 'zipcode', 'lat', "long"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  int64
#  1   price            21613 non-null  float64
#  2   bedrooms         21613 non-null  int64
#  3   bathrooms        21613 non-null  float64
#  4   sqft_living      21613 non-null  int64
#  5   sqft_lot         21613 non-null  int64
#  6   floors           21613 non-null  float64
#  7   waterfront       21613 non-null  int64
#  8   view             21613 non-null  int64
#  9   condition        21613 non-null  int64
#  10  grade            21613 non-null  int64
#  11  sqft_above       21613 non-null  int64
#  12  sqft_basement    21613 non-null  int64
#  13  yr_built         21613 non-null  int64
#  14  yr_renovated     21613 non-null  int64
#  15  sqft_living15    21613 non-null  int64
#  16  sqft_lot15       21613 non-null  int64
# ...

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Создайте датафрейм с клиентами:

# %%
clients = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295, 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242, 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 1189000207, 6821600300, 7137950720, 9510920050, 6131600255, 5428000070, 1788800910, 8100400160, 3123049142, 6306800010, 5083000375, 7920100025, 1951600150, 809001400, 339600110, 1622049154, 1099600250, 8563000110, 2768100205, 3995700435, 8861700030, 3303980210, 7731100066, 8146100580, 825069097, 3889100029, 9524100196]
})

# %%
clients.shape
# Out:
# (32, 2)

# %%
clients.head()
# Out:
#    client_id    house_id
# 0       1459  8965450190
# 1       4684  6823100225
# 2       3498  5104540330
# 3       3942  2131701075
# 4       4535  1522700060

# %% [markdown]
# Присоедините к таблице clients данные по домам через метод join

# %%
df_id = df.rename(columns={'id':'house_id'})
df_id = df_id.set_index("house_id")

# %%
df_id.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# house_id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# house_id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 1954400510           0     0          3      8        1680              0
#
# ...

# %%
clients_id = clients.set_index("house_id")

# %%
clients_id.head()
# Out:
#             client_id
# house_id
# 8965450190       1459
# 6823100225       4684
# 5104540330       3498
# 2131701075       3942
# 1522700060       4535

# %%
clients_id.join(df_id).shape
# Out:
# (33, 20)

# %%
clients_id.join(df_id).reset_index()
# Out:
#       house_id  client_id      price  bedrooms  bathrooms  sqft_living  \
# 0    339600110       4809   395000.0         3       2.50         1610
# 1    809001400       3113   925000.0         3       1.00         1630
# 2    825069097       1764   770000.0         3       2.50         2650
# 3   1099600250       2242   260000.0         3       1.75         1710
# 4   1189000207       2308   387000.0         2       2.50         1170
# 5   1522700060       4535   518000.0         4       2.75         2520
# 6   1622049154       2134   289900.0         3       1.75         1899
# 7   1788800910        939   190000.0         3       1.00         1200
# 8   1951600150       4213   180000.0         3       1.00         1610
# 9   2131701075       3942   420000.0         3       1.75         1720
# 10  2768100205       4929   519000.0         4       2.50         1950
# 11  3123049142        280   452000.0         3       2.25         2600
# ...

# %%
df[df["id"] == 5083000375]
# Out:
#               id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 3033  5083000375  170000.0         3        1.0         1310      9529
# 3034  5083000375  235000.0         3        1.0         1310      9529
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 3033     1.0           0     0          3      7        1310              0
# 3034     1.0           0     0          3      7        1310              0
#
#       yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  \
# 3033      1956             0           1330        9529                0
# 3034      1956             0           1330        9529                0
#
#      year_of_sale month_of_sale
# 3033         2014            10
# 3034         2015            03

# %%
# clients_id.join(df_id, how="right").shape

# %%
# clients_id.join(df_id, how="right").reset_index().head()
# JOIN not working correctly
# DataFrame.join is a bit of legacy method and apparently doesn't do column-on-column joins
# (originally it did index on column using the on parameter, hence the "legacy" designation).
# https://stackoverflow.com/questions/10114399/pandas-simple-join-not-working

# %%
# df2 = clients_id.join(df_id, on='house_id', how="right").reset_index()

# %%
# df2.info()

# %%
# df2["index"].unique()

# %%
clients_id.join(df_id, how="inner").shape
# Out:
# (33, 20)

# %%
clients_id.join(df_id, how="inner").reset_index()
# Out:
#       house_id  client_id      price  bedrooms  bathrooms  sqft_living  \
# 0    339600110       4809   395000.0         3       2.50         1610
# 1    809001400       3113   925000.0         3       1.00         1630
# 2    825069097       1764   770000.0         3       2.50         2650
# 3   1099600250       2242   260000.0         3       1.75         1710
# 4   1189000207       2308   387000.0         2       2.50         1170
# 5   1522700060       4535   518000.0         4       2.75         2520
# 6   1622049154       2134   289900.0         3       1.75         1899
# 7   1788800910        939   190000.0         3       1.00         1200
# 8   1951600150       4213   180000.0         3       1.00         1610
# 9   2131701075       3942   420000.0         3       1.75         1720
# 10  2768100205       4929   519000.0         4       2.50         1950
# 11  3123049142        280   452000.0         3       2.25         2600
# ...

# %%
# clients_id.join(df_id, how="outer").shape
# JOIN not working correctly

# %%
# clients_id.join(df_id, how="outer").reset_index().head(15)

# %% [markdown]
# Присоедините к таблице clients данные по домам через метод merge<br>
# Это нужно, чтобы понимать, какие дома покупались клиентами<br>
# house_id - это индексы датафрейма с домами

# %%
df2 = df.rename(columns={'id':'house_id'})

# %%
clients.merge(df2, on="house_id", how='left').shape
# Out:
# (33, 21)

# %%
clients.merge(df2, on="house_id", how='left')
# Out:
#     client_id    house_id      price  bedrooms  bathrooms  sqft_living  \
# 0        1459  8965450190   295000.0         3       2.50         1500
# 1        4684  6823100225   700000.0         4       1.75         1870
# 2        3498  5104540330   679000.0         4       2.50         3680
# 3        3942  2131701075   420000.0         3       1.75         1720
# 4        4535  1522700060   518000.0         4       2.75         2520
# 5        2308  1189000207   387000.0         2       2.50         1170
# 6        2866  6821600300   886000.0         3       2.25         2380
# 7        2765  7137950720   339100.0         4       2.50         2350
# 8        1472  9510920050   725000.0         3       2.50         2980
# 9        4236  6131600255   202500.0         3       2.00         1540
# 10       2295  5428000070   770000.0         5       3.50         4750
# 11        939  1788800910   190000.0         3       1.00         1200
# ...

# %%
df[df["id"] == 5083000375]
# Out:
#               id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 3033  5083000375  170000.0         3        1.0         1310      9529
# 3034  5083000375  235000.0         3        1.0         1310      9529
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 3033     1.0           0     0          3      7        1310              0
# 3034     1.0           0     0          3      7        1310              0
#
#       yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  \
# 3033      1956             0           1330        9529                0
# 3034      1956             0           1330        9529                0
#
#      year_of_sale month_of_sale
# 3033         2014            10
# 3034         2015            03

# %%
clients.merge(df2, on="house_id", how='right').shape
# Out:
# (21613, 21)

# %%
clients.merge(df2, on="house_id", how='right').head(15)
# Out:
#     client_id    house_id      price  bedrooms  bathrooms  sqft_living  \
# 0         NaN  7129300520   221900.0         3       1.00         1180
# 1         NaN  6414100192   538000.0         3       2.25         2570
# 2         NaN  5631500400   180000.0         2       1.00          770
# 3         NaN  2487200875   604000.0         4       3.00         1960
# 4         NaN  1954400510   510000.0         3       2.00         1680
# 5         NaN  7237550310  1225000.0         4       4.50         5420
# 6         NaN  1321400060   257500.0         3       2.25         1715
# 7         NaN  2008000270   291850.0         3       1.50         1060
# 8         NaN  2414600126   229500.0         3       1.00         1780
# 9         NaN  3793500160   323000.0         3       2.50         1890
# 10        NaN  1736800520   662500.0         3       2.50         3560
# 11        NaN  9212900260   468000.0         2       1.00         1160
# ...

# %%
clients.merge(df2, on="house_id", how='inner').shape
# Out:
# (33, 21)

# %%
clients.merge(df2, on="house_id", how='inner')
# Out:
#     client_id    house_id      price  bedrooms  bathrooms  sqft_living  \
# 0        1459  8965450190   295000.0         3       2.50         1500
# 1        4684  6823100225   700000.0         4       1.75         1870
# 2        3498  5104540330   679000.0         4       2.50         3680
# 3        3942  2131701075   420000.0         3       1.75         1720
# 4        4535  1522700060   518000.0         4       2.75         2520
# 5        2308  1189000207   387000.0         2       2.50         1170
# 6        2866  6821600300   886000.0         3       2.25         2380
# 7        2765  7137950720   339100.0         4       2.50         2350
# 8        1472  9510920050   725000.0         3       2.50         2980
# 9        4236  6131600255   202500.0         3       2.00         1540
# 10       2295  5428000070   770000.0         5       3.50         4750
# 11        939  1788800910   190000.0         3       1.00         1200
# ...

# %%
clients.merge(df2, on="house_id", how='outer').shape
# Out:
# (21613, 21)

# %%
clients.merge(df2, on="house_id", how='outer').head(50)
# Out:
#     client_id    house_id      price  bedrooms  bathrooms  sqft_living  \
# 0      1459.0  8965450190   295000.0         3       2.50         1500
# 1      4684.0  6823100225   700000.0         4       1.75         1870
# 2      3498.0  5104540330   679000.0         4       2.50         3680
# 3      3942.0  2131701075   420000.0         3       1.75         1720
# 4      4535.0  1522700060   518000.0         4       2.75         2520
# 5      2308.0  1189000207   387000.0         2       2.50         1170
# 6      2866.0  6821600300   886000.0         3       2.25         2380
# 7      2765.0  7137950720   339100.0         4       2.50         2350
# 8      1472.0  9510920050   725000.0         3       2.50         2980
# 9      4236.0  6131600255   202500.0         3       2.00         1540
# 10     2295.0  5428000070   770000.0         5       3.50         4750
# 11      939.0  1788800910   190000.0         3       1.00         1200
# ...

# %% [markdown]
# ### Задача 3

# %% [markdown]
# #### Составьте несколько сводных таблиц

# %% [markdown]
# Найдите среднюю стоимость домов в зависимости от количества спален<br>
# Отсортируйте от меньшей стоимости к большей

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
 df.groupby('bedrooms').agg({'price': ['mean']}).apply(lambda x: x.sort_values()).apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#                price
#                 mean
# bedrooms
# 1          317642.88
# 2          401372.68
# 0          409503.85
# 3          466232.08
# 11         520000.00
# 4          635419.50
# 33         640000.00
# 5          786599.83
# 10         819333.33
# 6          825520.64
# 9          893999.83
# 7          951184.66
# 8         1105076.92

# %%
df.groupby('bedrooms').agg({'price': ['mean']}).apply(lambda x: x.sort_values(ascending=False)).apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#                price
#                 mean
# bedrooms
# 8         1105076.92
# 7          951184.66
# 9          893999.83
# 6          825520.64
# 10         819333.33
# 5          786599.83
# 33         640000.00
# 4          635419.50
# 11         520000.00
# 3          466232.08
# 0          409503.85
# 2          401372.68
# 1          317642.88

# %% [markdown]
# Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
df.groupby('condition').agg({'price': ['min','mean', 'max']}).apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#                price
#                  min       mean         max
# condition
# 1           78000.00  334431.67  1500000.00
# 2           80000.00  327287.15  2555000.00
# 3           75000.00  542012.58  7062500.00
# 4           89000.00  521200.39  7700000.00
# 5          110000.00  612418.09  3650000.00

# %% [markdown]
# Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
df.groupby(['waterfront','view']).size().reset_index(name='counts')
# Out:
#    waterfront  view  counts
# 0           0     0   19489
# 1           0     1     331
# 2           0     2     955
# 3           0     3     491
# 4           0     4     184
# 5           1     1       1
# 6           1     2       8
# 7           1     3      19
# 8           1     4     135

# %%
df[
    (df["waterfront"] == 1) &
    (df["view"] == 4)
].shape[0]
# Out:
# 135

# %% [markdown]
# Каких домов в зависимости от этажности и количества спален больше?

# %%
df.groupby(['floors','bedrooms']).size().sort_values(ascending=False).reset_index(name='counts').head()
# Out:
#    floors  bedrooms  counts
# 0     1.0         3    5455
# 1     2.0         4    3682
# 2     2.0         3    3118
# 3     1.0         4    2383
# 4     1.0         2    1951

# %% [markdown]
# Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
df.groupby(['condition','grade']).agg({'price': ['mean']}).apply(lambda x: x.sort_values(ascending=False)).apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#                       price
#                        mean
# condition grade
# 4         13     5750000.00
# 3         13     3338636.36
# 4         12     2467961.54
# 5         12     2290000.00
#           11     2238477.27
# 3         12     2138601.08
# 4         11     1839916.43
# 2         10     1752500.00
# 5         10     1735830.36
# 3         11     1414401.44
# 4         10     1176284.59
# 5         9      1123419.90
# 3         10     1012934.13
# 1         8       932500.00
# 4         9       889664.52
# 5         8       736538.05
# 3         9       726587.80
# 2         9       715000.00
# 4         8       589527.30
# 3         8       510102.77
# 5         7       479667.75
# 2         8       421996.15
# 4         7       412923.07
# 3         7       385666.79
# 2         7       342698.52
# 1         7       334416.67
# 4         6       318731.57
# 5         6       310140.86
# 1         6       303813.64
# 3         6       290651.85
# ...
